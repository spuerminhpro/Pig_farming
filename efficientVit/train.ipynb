# %%
import os
import json
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms as T
from seg_head_instance_seg import efficientvit_instance_seg_custom
import pandas as pd
from data_load import get_transforms,CocoSegDataset,collate_fn,instance_loss_fn,save_and_plot_metrics,load_checkpoint
from torch.cuda.amp import autocast, GradScaler
from pycocotools import mask as mask_utils
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from pycocotools import mask as mask_utils
from sklearn.cluster import DBSCAN




device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define model parameters
num_classes = 2
img_size = 224
batch_size = 2

# Create a dummy input 
dummy_input = torch.randn(batch_size, 3, img_size, img_size)

# efficientvit_m0
model = efficientvit_instance_seg_custom(
    n_classes=num_classes,
    img_size=img_size,
    patch_size=16,
    embed_dim=[64, 128, 192],
    depth=[1, 2, 3],
    num_heads=[4, 4, 4],
    window_size=[7, 7, 7],
    kernels=[5, 5, 5, 5],
    down_ops=[['subsample', 2], ['subsample', 2], ['']],
    distillation=False,
    frozen_stages=0
)

# Evaluation 
model.eval()
with torch.no_grad():
    outputs = model(dummy_input)

seg_logits = outputs["seg_logits"]
embedding = outputs["embedding"]

print("Foreground segmentation logits shape:", seg_logits.shape)  #  [B, n_classes, H, W]
print("Instance embedding shape:", embedding.shape)               #  [B, emb_dim, H, W]
print("Total model parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Foreground segmentation logits shape: torch.Size([2, 2, 80, 80])
# Instance embedding shape: torch.Size([2, 16, 80, 80])
# Total model parameters: 3354652

# %%
from torchinfo import summary
model.to("cuda" if torch.cuda.is_available() else "cpu")
summary(model, input_size=(2, 3, 224, 224))
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                                            Output Shape              Param #
# ===================================================================================================================
# EfficientViTSeg                                                   [2, 16, 80, 80]           --
# ├─EfficientViT: 1-1                                               [2, 192, 1, 1]            --
# │    └─Sequential: 2-1                                            [2, 64, 14, 14]           --
# │    │    └─Conv2d_BN: 3-1                                        [2, 8, 112, 112]          (232)
# │    │    └─ReLU: 3-2                                             [2, 8, 112, 112]          --
# │    │    └─Conv2d_BN: 3-3                                        [2, 16, 56, 56]           (1,184)
# │    │    └─ReLU: 3-4                                             [2, 16, 56, 56]           --
# │    │    └─Conv2d_BN: 3-5                                        [2, 32, 28, 28]           (4,672)
# │    │    └─ReLU: 3-6                                             [2, 32, 28, 28]           --
# │    │    └─Conv2d_BN: 3-7                                        [2, 64, 14, 14]           (18,560)
# │    └─DSConv: 2-2                                                [2, 64, 14, 14]           --
# │    │    └─ConvLayer: 3-8                                        [2, 64, 14, 14]           704
# │    │    └─ConvLayer: 3-9                                        [2, 64, 14, 14]           4,224
# │    └─Sequential: 2-3                                            [2, 64, 7, 7]             --
# │    │    └─MBConv: 3-10                                          [2, 64, 7, 7]             69,312
# │    │    └─EfficientViTBlock: 3-11                               [2, 64, 7, 7]             44,548
# │    └─Sequential: 2-4                                            [2, 128, 2, 2]            --
# │    │    └─Sequential: 3-12                                      [2, 64, 7, 7]             17,472
# │    │    └─PatchMerging: 3-13                                    [2, 128, 4, 4]            85,824
# │    │    └─Sequential: 3-14                                      [2, 128, 4, 4]            67,712
# │    │    └─MBConv: 3-15                                          [2, 128, 2, 2]            269,696
# │    │    └─EfficientViTBlock: 3-16                               [2, 128, 2, 2]            162,512
# │    │    └─EfficientViTBlock: 3-17                               [2, 128, 2, 2]            162,512
# │    └─Sequential: 2-5                                            [2, 192, 1, 1]            --
# │    │    └─Sequential: 3-18                                      [2, 128, 2, 2]            67,712
# │    │    └─PatchMerging: 3-19                                    [2, 192, 1, 1]            302,592
# │    │    └─Sequential: 3-20                                      [2, 192, 1, 1]            150,720
# │    │    └─MBConv: 3-21                                          [2, 192, 1, 1]            601,152
# │    │    └─EfficientViTBlock: 3-22                               [2, 192, 1, 1]            356,420
# │    │    └─EfficientViTBlock: 3-23                               [2, 192, 1, 1]            356,420
# │    │    └─EfficientViTBlock: 3-24                               [2, 192, 1, 1]            356,420
# ├─InstanceSegHead: 1-2                                            [2, 16, 80, 80]           --
# │    └─ModuleDict: 2-6                                            --                        --
# │    │    └─ConvLayer: 3-25                                       [2, 64, 1, 1]             12,416
# │    │    └─ConvLayer: 3-26                                       [2, 64, 2, 2]             8,320
# │    │    └─ConvLayer: 3-27                                       [2, 64, 7, 7]             4,224
# │    └─OpSequential: 2-7                                          [2, 64, 80, 80]           --
# │    │    └─ResidualBlock: 3-28                                   [2, 64, 80, 80]           69,312
# │    │    └─ResidualBlock: 3-29                                   [2, 64, 80, 80]           69,312
# │    │    └─ResidualBlock: 3-30                                   [2, 64, 80, 80]           69,312
# │    └─OpSequential: 2-8                                          [2, 2, 80, 80]            --
# │    │    └─ConvLayer: 3-31                                       [2, 2, 80, 80]            132
# │    └─OpSequential: 2-9                                          [2, 16, 80, 80]           --
# │    │    └─ConvLayer: 3-32                                       [2, 256, 80, 80]          16,896
# │    │    └─ConvLayer: 3-33                                       [2, 16, 80, 80]           4,128
# ===================================================================================================================
# Total params: 3,354,652
# Trainable params: 3,330,004
# Non-trainable params: 24,648
# Total mult-adds (G): 1.67
# ===================================================================================================================
# Input size (MB): 1.20
# Forward/backward pass size (MB): 422.84
# Params size (MB): 13.42
# Estimated Total Size (MB): 437.46
# ===================================================================================================================

# %%
batch_size = 64  
num_epochs = 100
learning_rate = 2e-4
weight_decay = 1e-4

train_root = '/teamspace/uploads/pig_seg/annotations/train'  
val_root = '/teamspace/uploads/pig_seg/annotations/val'
train_ann_file = '/teamspace/uploads/pig_seg/annotations/train/_annotations.coco.json'
val_ann_file = '/teamspace/uploads/pig_seg/annotations/val/_annotations.coco.json'
train_transform = get_transforms(is_train=True)
val_transform = get_transforms(is_train=False)

train_dataset = CocoSegDataset(root=train_root, ann_file=train_ann_file, transform=train_transform)
val_dataset = CocoSegDataset(root=val_root, ann_file=val_ann_file, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, collate_fn=collate_fn)

os.makedirs("checkpoints", exist_ok=True)

# Initialize model without pretrained weights
model = efficientvit_instance_seg_custom(emb_dim=16, n_classes=2).to(device)

# Load the last trained checkpoint
checkpoint_path = 'checkpoints/efficientvit_pig_seg_final.pth'
seg_loss_fn = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scaler = GradScaler()
start_epoch = load_checkpoint(model, optimizer, checkpoint_path, device)
for epoch in range(start_epoch, num_epochs):
    model.train()
    total_loss = 0
    total_samples = 0
    for batch_idx, batch in enumerate(train_loader):
        imgs = batch['img'].to(device)
        actual_batch_size = len(imgs)
        gt_bboxes = [bbox.to(device) for bbox in batch['gt_bboxes']]
        gt_labels = [label.to(device) for label in batch['gt_labels']]
        gt_masks = [mask.to(device) for mask in batch['gt_masks']]
        with autocast():
            outputs = model(imgs)
            seg_logits = outputs['seg_logits']
            embeddings = outputs['embedding']
            gt_seg = torch.stack([mask.sum(dim=0).clamp(0, 1).long() for mask in gt_masks]).to(device)
            seg_loss = seg_loss_fn(seg_logits, gt_seg)
            inst_loss = instance_loss_fn(embeddings, gt_masks, actual_batch_size)
            loss = seg_loss + 2.0 * inst_loss
            if batch_idx % 10 == 0:
                print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx}/{len(train_loader)}, "
                      f"seg_loss={seg_loss.item():.4f}, inst_loss={inst_loss.item():.4f}, total_loss={loss.item():.4f}")
        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item() * actual_batch_size
        total_samples += actual_batch_size
    avg_loss = total_loss / total_samples if total_samples > 0 else float('nan')
    print(f"Epoch {epoch+1}/{num_epochs}, Average Loss: {avg_loss:.4f}")

    model.eval()
    val_coco = COCO(val_ann_file)
    val_preds = []
    with torch.no_grad():
        for batch in val_loader:
            imgs = batch['img'].to(device)
            outputs = model(imgs)
            seg_logits = outputs['seg_logits'].argmax(dim=1)
            embeddings = outputs['embedding']
            for b in range(imgs.size(0)):
                pred_class = seg_logits[b].cpu().numpy()
                mask = pred_class > 0
                if not mask.any():
                    print(f"Batch {b}: No foreground pixels detected, skipping DBSCAN")
                    continue
                emb = embeddings[b].permute(1, 2, 0).reshape(-1, 16).cpu().numpy()
                emb_flat = emb[mask.flatten()]
                if len(emb_flat) < 5:
                    print(f"Batch {b}: Too few foreground pixels ({len(emb_flat)}), skipping DBSCAN")
                    continue
                clustering = DBSCAN(eps=0.5, min_samples=5).fit(emb_flat)
                labels = clustering.labels_
                if (labels == -1).all():
                    print(f"Batch {b}: All points classified as noise by DBSCAN")
                    continue
                mask_flat = mask.flatten()
                mask_flat[mask_flat] = labels + 1
                pred_mask = mask_flat.reshape(80, 80)
                unique_ids = np.unique(pred_mask)
                if len(unique_ids) <= 1:
                    print(f"Batch {b}: No instances after clustering")
                    continue
                for inst_id in unique_ids:
                    if inst_id == 0: continue
                    inst_mask = (pred_mask == inst_id).astype(np.uint8)
                    rle = mask_utils.encode(np.asfortranarray(inst_mask))
                    rle['counts'] = rle['counts'].decode('utf-8')
                    val_preds.append({
                        'image_id': batch['image_id'][b],
                        'category_id': 1,
                        'segmentation': rle,
                        'score': 0.95
                    })
                print(f"Batch {b}: Added {len(unique_ids)-1} instance predictions")

    if val_preds:
        coco_dt = val_coco.loadRes(val_preds)
        coco_eval = COCOeval(val_coco, coco_dt, 'segm')
        coco_eval.evaluate()
        coco_eval.accumulate()
        coco_eval.summarize()
        mAP = coco_eval.stats[0]
        print(f"Validation mAP: {mAP:.4f}")
    else:
        print("No predictions generated for validation set. Setting mAP to 0.")
        mAP = 0.0

    save_and_plot_metrics(epoch, avg_loss, mAP)
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, f"checkpoints/model_epoch_{epoch+1}.pth")

torch.save({
    'epoch': num_epochs - 1,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}, "checkpoints/efficientvit_pig_seg_final.pth")
print("Training completed and model saved!")
# Out:
# loading annotations into memory...
# Done (t=2.83s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.12s)
# creating index...
# index created!
# Warning: 'optimizer_state_dict' not found in checkpoint, optimizer will use fresh state
# Resuming from checkpoint at epoch 82, starting at epoch 83
# Epoch 84/100, Batch 0/85, seg_loss=0.4757, inst_loss=0.0001, total_loss=0.4758
# Epoch 84/100, Batch 10/85, seg_loss=0.4964, inst_loss=0.0129, total_loss=0.5222
# Epoch 84/100, Batch 20/85, seg_loss=0.4887, inst_loss=0.0112, total_loss=0.5110
# Epoch 84/100, Batch 30/85, seg_loss=0.4869, inst_loss=0.0077, total_loss=0.5023
# Epoch 84/100, Batch 40/85, seg_loss=0.4848, inst_loss=0.0064, total_loss=0.4976
# Epoch 84/100, Batch 50/85, seg_loss=0.4846, inst_loss=0.0089, total_loss=0.5024
# Epoch 84/100, Batch 60/85, seg_loss=0.4831, inst_loss=0.0045, total_loss=0.4921
# Epoch 84/100, Batch 70/85, seg_loss=0.4791, inst_loss=0.0039, total_loss=0.4868
# Epoch 84/100, Batch 80/85, seg_loss=0.4822, inst_loss=0.0068, total_loss=0.4958
# Epoch 84/100, Average Loss: 0.5012
# loading annotations into memory...
# Done (t=0.25s)
# creating index...
# index created!
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: All points classified as noise by DBSCAN
# Batch 7: All points classified as noise by DBSCAN
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: All points classified as noise by DBSCAN
# Batch 16: All points classified as noise by DBSCAN
# Batch 17: Added 1 instance predictions
# Batch 18: All points classified as noise by DBSCAN
# Batch 19: All points classified as noise by DBSCAN
# Batch 20: Added 1 instance predictions
# Batch 21: All points classified as noise by DBSCAN
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: All points classified as noise by DBSCAN
# Batch 26: All points classified as noise by DBSCAN
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: All points classified as noise by DBSCAN
# Batch 32: Added 1 instance predictions
# Batch 33: All points classified as noise by DBSCAN
# Batch 34: Added 1 instance predictions
# Batch 35: All points classified as noise by DBSCAN
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: All points classified as noise by DBSCAN
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: All points classified as noise by DBSCAN
# Batch 52: All points classified as noise by DBSCAN
# Batch 53: Added 1 instance predictions
# Batch 54: All points classified as noise by DBSCAN
# Batch 55: Added 1 instance predictions
# Batch 56: All points classified as noise by DBSCAN
# Batch 57: All points classified as noise by DBSCAN
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: All points classified as noise by DBSCAN
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: All points classified as noise by DBSCAN
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: All points classified as noise by DBSCAN
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: All points classified as noise by DBSCAN
# Batch 38: All points classified as noise by DBSCAN
# Batch 39: Added 1 instance predictions
# Batch 40: All points classified as noise by DBSCAN
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: All points classified as noise by DBSCAN
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: All points classified as noise by DBSCAN
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: All points classified as noise by DBSCAN
# Batch 63: All points classified as noise by DBSCAN
# Batch 0: All points classified as noise by DBSCAN
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: All points classified as noise by DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: All points classified as noise by DBSCAN
# Batch 10: Added 1 instance predictions
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: All points classified as noise by DBSCAN
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: All points classified as noise by DBSCAN
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: All points classified as noise by DBSCAN
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: All points classified as noise by DBSCAN
# Batch 37: All points classified as noise by DBSCAN
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: All points classified as noise by DBSCAN
# Batch 42: Added 1 instance predictions
# Batch 43: All points classified as noise by DBSCAN
# Batch 44: Added 1 instance predictions
# Batch 45: All points classified as noise by DBSCAN
# Batch 46: Added 1 instance predictions
# Batch 47: All points classified as noise by DBSCAN
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: All points classified as noise by DBSCAN
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: All points classified as noise by DBSCAN
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: All points classified as noise by DBSCAN
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: All points classified as noise by DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: All points classified as noise by DBSCAN
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: All points classified as noise by DBSCAN
# Batch 20: Added 1 instance predictions
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Validation mAP: 0.0000
# Plot saved to checkpoints/training_metrics_epoch_84.png
# Epoch 85/100, Batch 0/85, seg_loss=0.4798, inst_loss=0.0019, total_loss=0.4836
# Epoch 85/100, Batch 10/85, seg_loss=0.4818, inst_loss=0.0017, total_loss=0.4852
# Epoch 85/100, Batch 20/85, seg_loss=0.4762, inst_loss=0.0022, total_loss=0.4806
# Epoch 85/100, Batch 30/85, seg_loss=0.4666, inst_loss=0.0007, total_loss=0.4679
# Epoch 85/100, Batch 40/85, seg_loss=0.4785, inst_loss=0.0012, total_loss=0.4809
# Epoch 85/100, Batch 50/85, seg_loss=0.4714, inst_loss=0.0025, total_loss=0.4764
# Epoch 85/100, Batch 60/85, seg_loss=0.4738, inst_loss=0.0047, total_loss=0.4832
# Epoch 85/100, Batch 70/85, seg_loss=0.4706, inst_loss=0.0030, total_loss=0.4766
# Epoch 85/100, Batch 80/85, seg_loss=0.4727, inst_loss=0.0082, total_loss=0.4891
# Epoch 85/100, Average Loss: 0.4822
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: All points classified as noise by DBSCAN
# Batch 14: Added 1 instance predictions
# Batch 15: All points classified as noise by DBSCAN
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Too few foreground pixels (1), skipping DBSCAN
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: All points classified as noise by DBSCAN
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: All points classified as noise by DBSCAN
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: All points classified as noise by DBSCAN
# Batch 43: Too few foreground pixels (3), skipping DBSCAN
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: All points classified as noise by DBSCAN
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: All points classified as noise by DBSCAN
# Batch 58: All points classified as noise by DBSCAN
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: All points classified as noise by DBSCAN
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Too few foreground pixels (4), skipping DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: All points classified as noise by DBSCAN
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: All points classified as noise by DBSCAN
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: All points classified as noise by DBSCAN
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: All points classified as noise by DBSCAN
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: All points classified as noise by DBSCAN
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: All points classified as noise by DBSCAN
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: All points classified as noise by DBSCAN
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: All points classified as noise by DBSCAN
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: All points classified as noise by DBSCAN
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: All points classified as noise by DBSCAN
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: All points classified as noise by DBSCAN
# Batch 25: Added 1 instance predictions
# Batch 26: All points classified as noise by DBSCAN
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: All points classified as noise by DBSCAN
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: All points classified as noise by DBSCAN
# Batch 36: Added 1 instance predictions
# Batch 37: All points classified as noise by DBSCAN
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: All points classified as noise by DBSCAN
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: All points classified as noise by DBSCAN
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: All points classified as noise by DBSCAN
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: All points classified as noise by DBSCAN
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: All points classified as noise by DBSCAN
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Too few foreground pixels (3), skipping DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: All points classified as noise by DBSCAN
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: All points classified as noise by DBSCAN
# Batch 18: Added 1 instance predictions
# Batch 19: All points classified as noise by DBSCAN
# Batch 20: Added 1 instance predictions
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Validation mAP: 0.0000
# Plot saved to checkpoints/training_metrics_epoch_85.png
# Epoch 86/100, Batch 0/85, seg_loss=0.4761, inst_loss=0.0010, total_loss=0.4782
# Epoch 86/100, Batch 10/85, seg_loss=0.4734, inst_loss=0.0006, total_loss=0.4746
# Epoch 86/100, Batch 20/85, seg_loss=0.4710, inst_loss=0.0025, total_loss=0.4760
# Epoch 86/100, Batch 30/85, seg_loss=0.4667, inst_loss=0.0044, total_loss=0.4755
# Epoch 86/100, Batch 40/85, seg_loss=0.4695, inst_loss=0.0148, total_loss=0.4991
# Epoch 86/100, Batch 50/85, seg_loss=0.4662, inst_loss=0.0000, total_loss=0.4662
# Epoch 86/100, Batch 60/85, seg_loss=0.4697, inst_loss=0.0008, total_loss=0.4714
# Epoch 86/100, Batch 70/85, seg_loss=0.4646, inst_loss=0.0017, total_loss=0.4679
# Epoch 86/100, Batch 80/85, seg_loss=0.4654, inst_loss=0.0007, total_loss=0.4669
# Epoch 86/100, Average Loss: 0.4724
# loading annotations into memory...
# Done (t=0.24s)
# creating index...
# index created!
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.20s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Validation mAP: 0.0000
# Plot saved to checkpoints/training_metrics_epoch_86.png
# Epoch 87/100, Batch 0/85, seg_loss=0.4678, inst_loss=0.0004, total_loss=0.4687
# Epoch 87/100, Batch 10/85, seg_loss=0.4617, inst_loss=0.0011, total_loss=0.4639
# Epoch 87/100, Batch 20/85, seg_loss=0.4581, inst_loss=0.0009, total_loss=0.4599
# Epoch 87/100, Batch 30/85, seg_loss=0.4597, inst_loss=0.0001, total_loss=0.4599
# Epoch 87/100, Batch 40/85, seg_loss=0.4595, inst_loss=0.0008, total_loss=0.4610
# Epoch 87/100, Batch 50/85, seg_loss=0.4643, inst_loss=0.0001, total_loss=0.4646
# Epoch 87/100, Batch 60/85, seg_loss=0.4584, inst_loss=0.0002, total_loss=0.4587
# Epoch 87/100, Batch 70/85, seg_loss=0.4628, inst_loss=0.0005, total_loss=0.4638
# Epoch 87/100, Batch 80/85, seg_loss=0.4570, inst_loss=0.0000, total_loss=0.4570
# Epoch 87/100, Average Loss: 0.4654
# loading annotations into memory...
# Done (t=0.24s)
# creating index...
# index created!
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.20s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Validation mAP: 0.0000
# Plot saved to checkpoints/training_metrics_epoch_87.png
# Epoch 88/100, Batch 0/85, seg_loss=0.4608, inst_loss=0.0006, total_loss=0.4619
# Epoch 88/100, Batch 10/85, seg_loss=0.4586, inst_loss=0.0000, total_loss=0.4586
# Epoch 88/100, Batch 20/85, seg_loss=0.4545, inst_loss=0.0023, total_loss=0.4591
# Epoch 88/100, Batch 30/85, seg_loss=0.4617, inst_loss=0.0003, total_loss=0.4623
# Epoch 88/100, Batch 40/85, seg_loss=0.4565, inst_loss=0.0000, total_loss=0.4565
# Epoch 88/100, Batch 50/85, seg_loss=0.4511, inst_loss=0.0015, total_loss=0.4541
# Epoch 88/100, Batch 60/85, seg_loss=0.4590, inst_loss=0.0005, total_loss=0.4601
# Epoch 88/100, Batch 70/85, seg_loss=0.4524, inst_loss=0.0003, total_loss=0.4530
# Epoch 88/100, Batch 80/85, seg_loss=0.4562, inst_loss=0.0001, total_loss=0.4563
# Epoch 88/100, Average Loss: 0.4582
# loading annotations into memory...
# Done (t=0.26s)
# creating index...
# index created!
# Batch 0: Added 1 instance predictions
# Batch 1: All points classified as noise by DBSCAN
# Batch 2: Added 1 instance predictions
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: All points classified as noise by DBSCAN
# Batch 5: All points classified as noise by DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: All points classified as noise by DBSCAN
# Batch 8: Too few foreground pixels (4), skipping DBSCAN
# Batch 9: All points classified as noise by DBSCAN
# Batch 10: All points classified as noise by DBSCAN
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: All points classified as noise by DBSCAN
# Batch 16: All points classified as noise by DBSCAN
# Batch 17: Added 1 instance predictions
# Batch 18: All points classified as noise by DBSCAN
# Batch 19: All points classified as noise by DBSCAN
# Batch 20: All points classified as noise by DBSCAN
# Batch 21: All points classified as noise by DBSCAN
# Batch 22: Added 1 instance predictions
# Batch 23: All points classified as noise by DBSCAN
# Batch 24: All points classified as noise by DBSCAN
# Batch 25: Added 1 instance predictions
# Batch 26: All points classified as noise by DBSCAN
# Batch 27: Too few foreground pixels (3), skipping DBSCAN
# Batch 28: All points classified as noise by DBSCAN
# Batch 29: All points classified as noise by DBSCAN
# Batch 30: All points classified as noise by DBSCAN
# Batch 31: All points classified as noise by DBSCAN
# Batch 32: All points classified as noise by DBSCAN
# Batch 33: All points classified as noise by DBSCAN
# Batch 34: Added 1 instance predictions
# Batch 35: All points classified as noise by DBSCAN
# Batch 36: All points classified as noise by DBSCAN
# Batch 37: All points classified as noise by DBSCAN
# Batch 38: All points classified as noise by DBSCAN
# Batch 39: All points classified as noise by DBSCAN
# Batch 40: All points classified as noise by DBSCAN
# Batch 41: All points classified as noise by DBSCAN
# Batch 42: Added 1 instance predictions
# Batch 43: All points classified as noise by DBSCAN
# Batch 44: All points classified as noise by DBSCAN
# Batch 45: All points classified as noise by DBSCAN
# Batch 46: All points classified as noise by DBSCAN
# Batch 47: Added 1 instance predictions
# Batch 48: All points classified as noise by DBSCAN
# Batch 49: All points classified as noise by DBSCAN
# Batch 50: All points classified as noise by DBSCAN
# Batch 51: All points classified as noise by DBSCAN
# Batch 52: All points classified as noise by DBSCAN
# Batch 53: All points classified as noise by DBSCAN
# Batch 54: All points classified as noise by DBSCAN
# Batch 55: All points classified as noise by DBSCAN
# Batch 56: All points classified as noise by DBSCAN
# Batch 57: All points classified as noise by DBSCAN
# Batch 58: Added 1 instance predictions
# Batch 59: All points classified as noise by DBSCAN
# Batch 60: All points classified as noise by DBSCAN
# Batch 61: All points classified as noise by DBSCAN
# Batch 62: All points classified as noise by DBSCAN
# Batch 63: All points classified as noise by DBSCAN
# Batch 0: All points classified as noise by DBSCAN
# Batch 1: All points classified as noise by DBSCAN
# Batch 2: All points classified as noise by DBSCAN
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: Too few foreground pixels (2), skipping DBSCAN
# Batch 6: All points classified as noise by DBSCAN
# Batch 7: All points classified as noise by DBSCAN
# Batch 8: Added 1 instance predictions
# Batch 9: All points classified as noise by DBSCAN
# Batch 10: Too few foreground pixels (1), skipping DBSCAN
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: All points classified as noise by DBSCAN
# Batch 14: All points classified as noise by DBSCAN
# Batch 15: All points classified as noise by DBSCAN
# Batch 16: All points classified as noise by DBSCAN
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: All points classified as noise by DBSCAN
# Batch 20: All points classified as noise by DBSCAN
# Batch 21: All points classified as noise by DBSCAN
# Batch 22: All points classified as noise by DBSCAN
# ...
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: All points classified as noise by DBSCAN
# Batch 55: All points classified as noise by DBSCAN
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: All points classified as noise by DBSCAN
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: All points classified as noise by DBSCAN
# Batch 63: Added 1 instance predictions
# Batch 0: All points classified as noise by DBSCAN
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: All points classified as noise by DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: All points classified as noise by DBSCAN
# Batch 8: Added 1 instance predictions
# Batch 9: All points classified as noise by DBSCAN
# Batch 10: Added 1 instance predictions
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: All points classified as noise by DBSCAN
# Batch 13: Added 1 instance predictions
# Batch 14: All points classified as noise by DBSCAN
# Batch 15: All points classified as noise by DBSCAN
# Batch 16: All points classified as noise by DBSCAN
# Batch 17: All points classified as noise by DBSCAN
# Batch 18: All points classified as noise by DBSCAN
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: All points classified as noise by DBSCAN
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: All points classified as noise by DBSCAN
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: All points classified as noise by DBSCAN
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: All points classified as noise by DBSCAN
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: All points classified as noise by DBSCAN
# Batch 41: All points classified as noise by DBSCAN
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: All points classified as noise by DBSCAN
# Batch 54: All points classified as noise by DBSCAN
# Batch 55: All points classified as noise by DBSCAN
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: All points classified as noise by DBSCAN
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: All points classified as noise by DBSCAN
# Batch 2: Added 1 instance predictions
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: All points classified as noise by DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: All points classified as noise by DBSCAN
# Batch 12: Added 1 instance predictions
# Batch 13: All points classified as noise by DBSCAN
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Validation mAP: 0.0000
# Plot saved to checkpoints/training_metrics_epoch_99.png
# Epoch 100/100, Batch 0/85, seg_loss=0.4110, inst_loss=0.0000, total_loss=0.4110
# Epoch 100/100, Batch 10/85, seg_loss=0.4053, inst_loss=0.0000, total_loss=0.4053
# Epoch 100/100, Batch 20/85, seg_loss=0.4110, inst_loss=0.0000, total_loss=0.4110
# Epoch 100/100, Batch 30/85, seg_loss=0.4063, inst_loss=0.0000, total_loss=0.4063
# Epoch 100/100, Batch 40/85, seg_loss=0.4049, inst_loss=0.0000, total_loss=0.4050
# Epoch 100/100, Batch 50/85, seg_loss=0.4073, inst_loss=0.0000, total_loss=0.4073
# Epoch 100/100, Batch 60/85, seg_loss=0.4111, inst_loss=0.0000, total_loss=0.4111
# Epoch 100/100, Batch 70/85, seg_loss=0.4012, inst_loss=0.0000, total_loss=0.4012
# Epoch 100/100, Batch 80/85, seg_loss=0.4087, inst_loss=0.0008, total_loss=0.4104
# Epoch 100/100, Average Loss: 0.4073
# loading annotations into memory...
# Done (t=0.27s)
# creating index...
# index created!
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: All points classified as noise by DBSCAN
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: All points classified as noise by DBSCAN
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: All points classified as noise by DBSCAN
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: Added 1 instance predictions
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: All points classified as noise by DBSCAN
# Batch 4: Added 1 instance predictions
# Batch 5: Added 1 instance predictions
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Batch 21: Added 1 instance predictions
# Batch 22: Added 1 instance predictions
# Batch 23: Added 1 instance predictions
# Batch 24: Added 1 instance predictions
# Batch 25: Added 1 instance predictions
# Batch 26: Added 1 instance predictions
# Batch 27: Added 1 instance predictions
# Batch 28: Added 1 instance predictions
# Batch 29: Added 1 instance predictions
# Batch 30: Added 1 instance predictions
# Batch 31: Added 1 instance predictions
# Batch 32: Added 1 instance predictions
# Batch 33: Added 1 instance predictions
# Batch 34: Added 1 instance predictions
# Batch 35: Added 1 instance predictions
# Batch 36: All points classified as noise by DBSCAN
# Batch 37: Added 1 instance predictions
# Batch 38: Added 1 instance predictions
# Batch 39: Added 1 instance predictions
# Batch 40: Added 1 instance predictions
# Batch 41: Added 1 instance predictions
# Batch 42: Added 1 instance predictions
# Batch 43: Added 1 instance predictions
# Batch 44: Added 1 instance predictions
# Batch 45: Added 1 instance predictions
# Batch 46: Added 1 instance predictions
# Batch 47: Added 1 instance predictions
# Batch 48: Added 1 instance predictions
# Batch 49: Added 1 instance predictions
# Batch 50: Added 1 instance predictions
# Batch 51: Added 1 instance predictions
# Batch 52: Added 1 instance predictions
# Batch 53: Added 1 instance predictions
# Batch 54: Added 1 instance predictions
# Batch 55: Added 1 instance predictions
# Batch 56: Added 1 instance predictions
# Batch 57: Added 1 instance predictions
# Batch 58: Added 1 instance predictions
# Batch 59: Added 1 instance predictions
# Batch 60: Added 1 instance predictions
# Batch 61: Added 1 instance predictions
# Batch 62: Added 1 instance predictions
# Batch 63: Added 1 instance predictions
# Batch 0: Added 1 instance predictions
# Batch 1: Added 1 instance predictions
# Batch 2: Added 1 instance predictions
# Batch 3: Added 1 instance predictions
# Batch 4: Added 1 instance predictions
# Batch 5: All points classified as noise by DBSCAN
# Batch 6: Added 1 instance predictions
# Batch 7: Added 1 instance predictions
# Batch 8: Added 1 instance predictions
# Batch 9: Added 1 instance predictions
# Batch 10: Added 1 instance predictions
# Batch 11: Added 1 instance predictions
# Batch 12: Added 1 instance predictions
# Batch 13: Added 1 instance predictions
# Batch 14: Added 1 instance predictions
# Batch 15: Added 1 instance predictions
# Batch 16: Added 1 instance predictions
# Batch 17: Added 1 instance predictions
# Batch 18: Added 1 instance predictions
# Batch 19: Added 1 instance predictions
# Batch 20: Added 1 instance predictions
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Validation mAP: 0.0000
# Plot saved to checkpoints/training_metrics_epoch_100.png
# Training completed and model saved!
